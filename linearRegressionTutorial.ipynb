# %%
#Import Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

# %%
#Read csv File and Load to a dataframe

df = pd.read_csv('data/advertising.csv')
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
#create x,y series

x_series = df["TV"]
y_series = df["Sales"]

#draw scatter plot

plt.scatter(x_series, y_series)
plt.xlabel("TV Advertising")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
#linear regression

# x and y are 1-D arrays. We need to convert them into 2-D arrays to fit the regression model.
# we first convert series into numpy arrays and use reshape function.

x = x_series.to_numpy().reshape(-1,1)
y = y_series.to_numpy().reshape(-1,1)

#train model
model = LinearRegression()
model.fit(x,y)
y_pred = model.predict(x)

#plot scatterplot
plt.scatter(x,y)

#plot regression_line
plt.plot(x,y_pred, color='red', linewidth=2)

# %%
#To retrieve the slope:
m=model.coef_
print(m)

#For retrieving the intercept:
c=model.intercept_
print(c)
# Out:
# [[0.05546477]]
# [6.97482149]

# %%
predicted_400=model.predict([[400]])
print(predicted_400)

predicted_350=model.predict([[350]])
print(predicted_350)
# Out:
# [[29.16072968]]
# [[26.38749115]]

# %%
plt.scatter(x,y)
plt.plot(x,y_pred, color='red', linewidth=2)
plt.scatter(400, predicted_400)
plt.scatter(350, predicted_350)

# %% [markdown]
# # Exercise

# %% [markdown]
# Import the csv file in location "data/advertising.csv" and load into a dataframe.
#
# Build a linear regression model with 'Sales' as the dependent variable and 'Radio' as the independent variable.
